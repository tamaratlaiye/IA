# %%
import math
import random
import time

LAMBDA = 8

def simu():
    cajas = {1: [], 2: [], 3: [], 4: []}
    atendidos = {1: 0, 2: 0, 3: 0, 4: 0}
    registros_por_hora = {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
    
    for hora in range(8):
        arrivals = poisson_random(LAMBDA)
        
        for x in range(arrivals):
            valor = (x % 4) + 1
            formarse(cajas[valor], valor)
            
        for caja_num, caja in cajas.items():
            caja.sort(key=lambda x: sum([registro["Tiempo de atención"] for registro in registros_por_hora[hora + 1] if registro["Caja"] == caja_num]))
            
        for caja_num, caja in cajas.items():
            while caja:
                cliente_actual = caja.pop(0)
                caja_destino = min(cajas.keys(), key=lambda x: sum([registro["Tiempo de atención"] for registro in registros_por_hora[hora + 1] if registro["Caja"] == x]))
                tiempo_inicio = time.time()
                tiempo_atencion = random.randint(1, 10)
                # time.sleep(tiempo_atencion)  # Comentado para depuración
                tiempo_fin = time.time()
                tiempo_total_atencion = tiempo_fin - tiempo_inicio
                atendidos[caja_destino] += 1
                registro = {
                    "Cliente": atendidos[caja_destino],
                    "Caja": caja_destino,
                    "Hora": hora + 1,
                    "Tiempo de atención": tiempo_atencion
                }
                registros_por_hora[hora + 1].append(registro)
                
        print(f"En la hora {hora + 1}, llegaron {arrivals} clientes.")
    
    for hora, registros_hora in registros_por_hora.items():
        print(f"Registros para la hora {hora}:")
        registros_hora.sort(key=lambda x: x['Cliente'])  # Ordenar por orden de atención
        for registro in registros_hora:
            print(registro)
    
def poisson_random(lambda_val):
    k = 0
    p = 1.0
    exp_lambda = math.exp(-lambda_val)

    while p >= exp_lambda:
        k += 1
        p *= random.random()

    return k - 1
    
def formarse(cola, x):
    cola.append(x)
    
simu()
# Out:
# En la hora 1, llegaron 10 clientes.
# En la hora 2, llegaron 6 clientes.
# En la hora 3, llegaron 6 clientes.
# En la hora 4, llegaron 9 clientes.
# En la hora 5, llegaron 8 clientes.
# En la hora 6, llegaron 8 clientes.
# En la hora 7, llegaron 9 clientes.
# En la hora 8, llegaron 12 clientes.
# Registros para la hora 1:
# {'Cliente': 1, 'Caja': 1, 'Hora': 1, 'Tiempo de atención': 9}
# {'Cliente': 1, 'Caja': 2, 'Hora': 1, 'Tiempo de atención': 6}
# {'Cliente': 1, 'Caja': 3, 'Hora': 1, 'Tiempo de atención': 8}
# {'Cliente': 1, 'Caja': 4, 'Hora': 1, 'Tiempo de atención': 3}
# {'Cliente': 2, 'Caja': 4, 'Hora': 1, 'Tiempo de atención': 7}
# {'Cliente': 2, 'Caja': 2, 'Hora': 1, 'Tiempo de atención': 5}
# {'Cliente': 2, 'Caja': 3, 'Hora': 1, 'Tiempo de atención': 9}
# {'Cliente': 2, 'Caja': 1, 'Hora': 1, 'Tiempo de atención': 2}
# {'Cliente': 3, 'Caja': 4, 'Hora': 1, 'Tiempo de atención': 8}
# {'Cliente': 3, 'Caja': 1, 'Hora': 1, 'Tiempo de atención': 2}
# Registros para la hora 2:
# {'Cliente': 3, 'Caja': 2, 'Hora': 2, 'Tiempo de atención': 2}
# {'Cliente': 3, 'Caja': 3, 'Hora': 2, 'Tiempo de atención': 2}
# {'Cliente': 4, 'Caja': 1, 'Hora': 2, 'Tiempo de atención': 1}
# {'Cliente': 4, 'Caja': 4, 'Hora': 2, 'Tiempo de atención': 1}
# {'Cliente': 5, 'Caja': 1, 'Hora': 2, 'Tiempo de atención': 5}
# {'Cliente': 5, 'Caja': 4, 'Hora': 2, 'Tiempo de atención': 5}
# Registros para la hora 3:
# {'Cliente': 4, 'Caja': 2, 'Hora': 3, 'Tiempo de atención': 4}
# {'Cliente': 4, 'Caja': 3, 'Hora': 3, 'Tiempo de atención': 5}
# {'Cliente': 5, 'Caja': 2, 'Hora': 3, 'Tiempo de atención': 7}
# {'Cliente': 6, 'Caja': 1, 'Hora': 3, 'Tiempo de atención': 8}
# {'Cliente': 6, 'Caja': 4, 'Hora': 3, 'Tiempo de atención': 1}
# {'Cliente': 7, 'Caja': 4, 'Hora': 3, 'Tiempo de atención': 8}
# Registros para la hora 4:
# {'Cliente': 5, 'Caja': 3, 'Hora': 4, 'Tiempo de atención': 4}
# {'Cliente': 6, 'Caja': 2, 'Hora': 4, 'Tiempo de atención': 3}
# {'Cliente': 6, 'Caja': 3, 'Hora': 4, 'Tiempo de atención': 3}
# {'Cliente': 7, 'Caja': 1, 'Hora': 4, 'Tiempo de atención': 4}
# {'Cliente': 7, 'Caja': 2, 'Hora': 4, 'Tiempo de atención': 9}
# {'Cliente': 7, 'Caja': 3, 'Hora': 4, 'Tiempo de atención': 8}
# {'Cliente': 8, 'Caja': 4, 'Hora': 4, 'Tiempo de atención': 10}
# {'Cliente': 8, 'Caja': 1, 'Hora': 4, 'Tiempo de atención': 5}
# {'Cliente': 9, 'Caja': 1, 'Hora': 4, 'Tiempo de atención': 7}
# Registros para la hora 5:
# {'Cliente': 8, 'Caja': 2, 'Hora': 5, 'Tiempo de atención': 4}
# {'Cliente': 8, 'Caja': 3, 'Hora': 5, 'Tiempo de atención': 8}
# {'Cliente': 9, 'Caja': 4, 'Hora': 5, 'Tiempo de atención': 1}
# {'Cliente': 9, 'Caja': 2, 'Hora': 5, 'Tiempo de atención': 2}
# {'Cliente': 10, 'Caja': 1, 'Hora': 5, 'Tiempo de atención': 9}
# {'Cliente': 10, 'Caja': 4, 'Hora': 5, 'Tiempo de atención': 3}
# {'Cliente': 10, 'Caja': 2, 'Hora': 5, 'Tiempo de atención': 8}
# {'Cliente': 11, 'Caja': 4, 'Hora': 5, 'Tiempo de atención': 3}
# Registros para la hora 6:
# {'Cliente': 9, 'Caja': 3, 'Hora': 6, 'Tiempo de atención': 9}
# {'Cliente': 10, 'Caja': 3, 'Hora': 6, 'Tiempo de atención': 2}
# {'Cliente': 11, 'Caja': 1, 'Hora': 6, 'Tiempo de atención': 5}
# {'Cliente': 11, 'Caja': 2, 'Hora': 6, 'Tiempo de atención': 8}
# {'Cliente': 12, 'Caja': 4, 'Hora': 6, 'Tiempo de atención': 10}
# {'Cliente': 12, 'Caja': 1, 'Hora': 6, 'Tiempo de atención': 6}
# {'Cliente': 12, 'Caja': 2, 'Hora': 6, 'Tiempo de atención': 2}
# {'Cliente': 13, 'Caja': 2, 'Hora': 6, 'Tiempo de atención': 2}
# Registros para la hora 7:
# {'Cliente': 11, 'Caja': 3, 'Hora': 7, 'Tiempo de atención': 9}
# {'Cliente': 12, 'Caja': 3, 'Hora': 7, 'Tiempo de atención': 9}
# {'Cliente': 13, 'Caja': 1, 'Hora': 7, 'Tiempo de atención': 9}
# {'Cliente': 13, 'Caja': 4, 'Hora': 7, 'Tiempo de atención': 3}
# {'Cliente': 14, 'Caja': 2, 'Hora': 7, 'Tiempo de atención': 3}
# {'Cliente': 14, 'Caja': 4, 'Hora': 7, 'Tiempo de atención': 7}
# {'Cliente': 14, 'Caja': 1, 'Hora': 7, 'Tiempo de atención': 2}
# {'Cliente': 15, 'Caja': 2, 'Hora': 7, 'Tiempo de atención': 8}
# {'Cliente': 15, 'Caja': 4, 'Hora': 7, 'Tiempo de atención': 10}
# Registros para la hora 8:
# {'Cliente': 13, 'Caja': 3, 'Hora': 8, 'Tiempo de atención': 9}
# {'Cliente': 14, 'Caja': 3, 'Hora': 8, 'Tiempo de atención': 4}
# {'Cliente': 15, 'Caja': 1, 'Hora': 8, 'Tiempo de atención': 2}
# {'Cliente': 15, 'Caja': 3, 'Hora': 8, 'Tiempo de atención': 2}
# {'Cliente': 16, 'Caja': 2, 'Hora': 8, 'Tiempo de atención': 6}
# {'Cliente': 16, 'Caja': 4, 'Hora': 8, 'Tiempo de atención': 6}
# {'Cliente': 16, 'Caja': 1, 'Hora': 8, 'Tiempo de atención': 5}
# {'Cliente': 17, 'Caja': 2, 'Hora': 8, 'Tiempo de atención': 9}
# {'Cliente': 17, 'Caja': 4, 'Hora': 8, 'Tiempo de atención': 5}
# {'Cliente': 17, 'Caja': 1, 'Hora': 8, 'Tiempo de atención': 2}
# {'Cliente': 18, 'Caja': 1, 'Hora': 8, 'Tiempo de atención': 10}
# {'Cliente': 18, 'Caja': 4, 'Hora': 8, 'Tiempo de atención': 3}
